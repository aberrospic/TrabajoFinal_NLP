# %%
# !pip install googlesearch-python openai requests beautifulsoup4 pymupdf pdf2image pytesseract --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.8 MB/s eta 0:00:00

# %% [markdown]
# ## Módulo de Búsqueda en Internet

# %%
from googlesearch import search
import requests
from bs4 import BeautifulSoup

def buscar_en_internet(query, num_results=5, lang="es"):
    urls = search(query, num_results=num_results, lang=lang, advanced=True)
    return urls

def analizar_pagina(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        contenido_principal = soup.find('main') or soup.find('article') or soup
        parrafos = contenido_principal.find_all('p')
        texto_largo = " ".join([p.get_text().strip() for p in parrafos if len(p.get_text().strip()) > 50])
        return texto_largo
    except requests.RequestException as e:
        print(f'Error al acceder a {url}: {e}')
        return ""

# %% [markdown]
# ## Módulo de Extracción de Texto de PDFs

# %%
import pymupdf
import pytesseract
from pdf2image import convert_from_path
import numpy as np
import cv2

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def is_digitalized(pdf_path):
    pdf_document = pymupdf.open(pdf_path)
    first_page = pdf_document.load_page(0)
    text = first_page.get_text()
    return bool(text.strip())

def extract_text_from_pdf(pdf_path):
    pdf_document = pymupdf.open(pdf_path)
    num_pages = pdf_document.page_count
    text_by_page = [pdf_document.load_page(page_num).get_text() for page_num in range(num_pages)]
    return text_by_page

def extract_text_from_scanned_pdf(pdf_path):
    images = convert_from_path(pdf_path)
    text_by_page = []
    for image in images:
        image_np = np.array(image)
        gray = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        text_by_page.append(text)
    return text_by_page

def extract_text_from_pdf_file(pdf_path):
    if is_digitalized(pdf_path):
        return extract_text_from_pdf(pdf_path)
    else:
        return extract_text_from_scanned_pdf(pdf_path)

# %% [markdown]
# ## Módulo de Interacción con el Usuario

# %%
class ConversationMemory:
    def __init__(self):
        self.history = []

    def add_message(self, role, content):
        self.history.append({"role": role, "content": content})

    def get_context(self):
        return self.history

memory = ConversationMemory()

def handle_conversation(user_input, model, api_key):
    memory.add_message("user", user_input)
    context = memory.get_context()
    client = OpenAI(api_key=api_key)

    try:
        completion = client.Completion.create(
            model=model,
            messages=context,
            temperature=0.5,
            top_p=1,
            max_tokens=1024,
            stream=True
        )

        ai_response = ""
        for chunk in completion:
            if chunk.choices[0].delta.content:
                ai_response += chunk.choices[0].delta.content
                print(chunk.choices[0].delta.content, end="")

        memory.add_message("assistant", ai_response)
        return ai_response
    except Exception as e:
        print(f"Error al procesar la solicitud: {e}")
        return None

# %% [markdown]
# # Version 1 del chatbot

# %% [markdown]
# ## Integración con el Modelo Llama3

# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
import fitz  # PyMuPDF
import pytesseract
from pdf2image import convert_from_path
import numpy as np
import cv2
import os

client = OpenAI(
    base_url="https://integrate.api.nvidia.com/v1",
    api_key="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"
)

class ConversationMemory:
    def __init__(self):
        self.history = []

    def add_message(self, role, content):
        self.history.append({"role": role, "content": content})

    def get_context(self):
        return self.history

memory = ConversationMemory()

def handle_conversation(user_input):
    memory.add_message("user", user_input)
    context = memory.get_context()

    try:
        completion = client.chat.completions.create(
            model="meta/llama3-70b-instruct",
            messages=context,
            temperature=0.5,
            top_p=1,
            max_tokens=1024,
            stream=True
        )

        ai_response = ""
        for chunk in completion:
            if chunk.choices[0].delta.content:
                ai_response += chunk.choices[0].delta.content

        memory.add_message("assistant", ai_response)
        return ai_response
    except Exception as e:
        print(f"Error al procesar la solicitud: {e}")
        return None

def buscar_en_internet(query, num_results=5, lang="es"):
    try:
        response = requests.get(f"https://www.google.com/search?q={query}&num={num_results}&hl={lang}")
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True) if 'url?q=' in a['href']]
        return [link.split('url?q=')[1].split('&sa=U')[0] for link in links]
    except Exception as e:
        print(f"Error al buscar en internet: {e}")
        return []

def analizar_pagina(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        contenido_principal = soup.find('main') or soup.find('article') or soup
        parrafos = contenido_principal.find_all('p')
        texto_largo = " ".join([p.get_text().strip() for p in parrafos if len(p.get_text().strip()) > 50])
        return texto_largo
    except requests.RequestException as e:
        print(f'Error al acceder a {url}: {e}')
        return ""

def descargar_pdf(url, nombre_archivo):
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(nombre_archivo, 'wb') as file:
            file.write(response.content)
        return nombre_archivo
    except requests.RequestException as e:
        print(f"Error al descargar el PDF: {e}")
        return None

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'  # Ajusta esto si es necesario

def is_digitalized(pdf_path):
    pdf_document = fitz.open(pdf_path)
    first_page = pdf_document.load_page(0)
    text = first_page.get_text()
    return bool(text.strip())

def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    num_pages = pdf_document.page_count
    text_by_page = [pdf_document.load_page(page_num).get_text() for page_num in range(num_pages)]
    return text_by_page

def extract_text_from_scanned_pdf(pdf_path):
    images = convert_from_path(pdf_path)
    text_by_page = []
    for image in images:
        image_np = np.array(image)
        gray = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        text_by_page.append(text)
    return text_by_page

def extract_text_from_pdf_file(pdf_path):
    if is_digitalized(pdf_path):
        return extract_text_from_pdf(pdf_path)
    else:
        return extract_text_from_scanned_pdf(pdf_path)

def process_request(user_input):
    if "buscar" in user_input:
        query = user_input.replace("buscar", "").strip()
        urls = buscar_en_internet(query)
        for url in urls:
            contenido = analizar_pagina(url)
            if contenido:
                response = handle_conversation(contenido)
                print(f"Assistant: {response}")

    elif "descargar pdf" in user_input:
        url = user_input.replace("descargar pdf", "").strip()
        pdf_path = descargar_pdf(url, "descargado.pdf")
        if pdf_path:
            try:
                text_by_page = extract_text_from_pdf_file(pdf_path)
                for page_text in text_by_page:
                    response = handle_conversation(page_text)
                    print(f"Assistant: {response}")
            except FileNotFoundError as e:
                print(f"Error: {e}")

    else:
        response = handle_conversation(user_input)
        print(f"Assistant: {response}")

# Ejemplo de uso
prompts = [
    "buscar cómo armar un backend",
    "descargar pdf https://url.del.pdf/documento.pdf",  # Asegúrate de proporcionar un URL válido de un PDF
    "Describe the significance of the Battle of Hastings."
]

for prompt in prompts:
    process_request(prompt)

# Asegúrate de eliminar el archivo descargado después de usarlo
if os.path.exists("descargado.pdf"):
    os.remove("descargado.pdf")
# Out:
# Error al acceder a https://maps.google.com/maps%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26hl%3Des%26um%3D1%26ie%3DUTF-8%26ved%3D1t:200713%26ictx%3D111&opi=89978449: 404 Client Error: Not Found for url: https://maps.google.com/maps%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26hl%3Des%26um%3D1%26ie%3DUTF-8%26ved%3D1t:200713%26ictx%3D111&opi=89978449
# Error al acceder a /search%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26sca_esv%3D458fc5d25ecd7a59%26sca_upv%3D1%26hl%3Des%26ie%3DUTF-8%26tbm%3Dshop%26source%3Dlnms%26ved%3D1t:200713%26ictx%3D111&opi=89978449: No connection adapters were found for '/search%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26sca_esv%3D458fc5d25ecd7a59%26sca_upv%3D1%26hl%3Des%26ie%3DUTF-8%26tbm%3Dshop%26source%3Dlnms%26ved%3D1t:200713%26ictx%3D111&opi=89978449'
# Error al acceder a https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk
# Error al acceder a https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk
# Assistant: Este artículo explica qué es un backend para una aplicación móvil y cómo construir uno. Comienza describiendo la diferencia entre frontend y backend, y cómo el backend es la parte de la aplicación que se ejecuta en un servidor, en lugar de en el propio dispositivo.
#
# El artículo destaca que un backend es necesario para almacenar y administrar datos, autenticar usuarios, procesar y analizar datos y comunicarse con otros sistemas o servicios. También se mencionan las ventajas de tener un backend, como la capacidad de recopilar análisis, enviar notificaciones automáticas, supervisar aplicaciones y recopilar informes de fallas.
#
# Luego, se presentan los diferentes tipos de backend, incluyendo:
#
# * Software como Servicio (SaaS): una aplicación de software que se ofrece como un servicio en la nube.
# * Backend como Servicio (BaaS): una plataforma que automatiza el desarrollo del backend y se encarga de la infraestructura de la nube.
# * Backend personalizado: una opción más poderosa y flexible que requiere un desarrollo personalizado.
#
# Se discuten también los costos de desarrollar un backend, que varían según la complejidad de la aplicación, la cantidad de funciones y la escalabilidad.
#
# Finalmente, el artículo proporciona un tutorial práctico sobre cómo construir un backend para una aplicación móvil utilizando Back4app, una plataforma de BaaS de código abierto. El tutorial cubre los siguientes temas:
#
# * Crear una aplicación en Back4app
# * Definir la estructura de la base de datos
# * Habilitar el panel de administración para una administración más sencilla
# * Proteger el backend utilizando ACL/CLPs
# * Probar el backend utilizando la Consola API integrada
# * Conectar el backend a la aplicación móvil
#
# En resumen, este artículo proporciona una guía completa para entender y construir un backend para una aplicación móvil, incluyendo las ventajas y desventajas de los diferentes tipos de backend y un tutorial práctico para construir un backend utilizando Back4app.
# Assistant: Este artículo presenta las 10 mejores soluciones de backend para desarrollar aplicaciones web y móviles. Un backend avanzado debe permitir a los desarrolladores crear plataformas interoperables que puedan manejar grandes volúmenes de carga de trabajo. A continuación, se presentan las soluciones de backend más populares y respetadas:
#
# 1. **Back4app**: un proveedor de backend como servicio de código abierto que ayuda a los desarrolladores a crear aplicaciones móviles y web amplias y escalables a gran velocidad.
# 2. **Firebase**: un conjunto de herramientas para crear, mejorar y hacer crecer su aplicación, que cubre una gran parte de los servicios que normalmente tendría que crear usted mismo.
# 3. **Express.js**: un marco de aplicación web flexible y mínimo que proporciona un conjunto sólido de características para desarrollar aplicaciones móviles y web.
# 4. **Laravel**: un marco de desarrollo de backend con todas las funciones, basado en PHP, que permite a los ingenieros crear excelentes aplicaciones.
# 5. **Django**: un marco de desarrollo web backend de código abierto gratuito, que se utiliza para desarrollar API y aplicaciones web backend de alta calidad rápidamente.
# 6. **Ruby on Rails**: una solución completamente MVC del lado del servidor, que ofrece servicios web predeterminados, estructura de base de datos y páginas web.
# 7. **CakePHP**: una solución de backend basada en PHP, que permite a los desarrolladores crear aplicaciones web a mayor velocidad con una codificación mínima.
# 8. **Meteor**: un marco JavaScript de pila completa, que se utiliza para aplicaciones móviles y web, y se ha convertido en una opción popular entre los desarrolladores por ser perfecto y una de las soluciones más convenientes para la creación rápida de prototipos.
# 9. **Flask**: un marco de desarrollo web backend en Python, que es perfecto para crear aplicaciones web backend extremadamente livianas.
# 10. **Nest**: una solución para crear aplicaciones del lado del servidor Node.js escalables y eficientes, que utiliza JavaScript progresivo y es completamente compatible con TypeScript.
#
# Cada una de estas soluciones de backend tiene sus ventajas y desventajas, y es importante evaluarlas sabiamente en función de las necesidades y especificaciones de los requisitos de su proyecto.
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 8245 tokens (7221 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"79f4da1b-2fbc-4c04-a263-0147fb2c7a8f"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 8290 tokens (7266 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"34a31939-efe7-4ce2-930b-5d7bf59d50da"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 8335 tokens (7311 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"95ffb9a1-dcf4-4ac1-a506-61df48c59e27"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 8380 tokens (7356 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"88f386a8-70e0-4a09-90b9-db817c1019d7"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 10889 tokens (9865 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"d199dfe5-c37a-4fcf-b27e-dc746fb28994"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 14767 tokens (13743 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"29c0fa65-e099-4aa6-b61a-00cd3c48cc3e"}
# Assistant: None
# Error al acceder a https://accounts.google.com/ServiceLogin%3Fcontinue%3Dhttps://www.google.com/search%253Fq%253Dc%2525C3%2525B3mo%252Barmar%252Bun%252Bbackend%2526num%253D5%2526hl%253Des%26hl%3Des&opi=89978449: 404 Client Error: Not Found for url: https://accounts.google.com/ServiceLogin%3Fcontinue%3Dhttps://www.google.com/search%253Fq%253Dc%2525C3%2525B3mo%252Barmar%252Bun%252Bbackend%2526num%253D5%2526hl%253Des%26hl%3Des&opi=89978449
# Error al descargar el PDF: HTTPSConnectionPool(host='url.del.pdf', port=443): Max retries exceeded with url: /documento.pdf (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7bcc65b111e0>: Failed to resolve 'url.del.pdf' ([Errno -2] Name or service not known)"))
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"This model's maximum context length is 8192 tokens. However, you requested 14781 tokens (13757 in the messages, 1024 in the completion). Please reduce the length of the messages or completion.","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"78d8dc08-88bb-41b2-80e8-e0e10d5102e9"}
# Assistant: None

# %% [markdown]
# # Version Final

# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
import fitz  # PyMuPDF
import pytesseract
from pdf2image import convert_from_path
import numpy as np
import cv2
import os

client = OpenAI(
    base_url="https://integrate.api.nvidia.com/v1",
    api_key="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"
)

class ConversationMemory:
    def __init__(self, max_tokens=8192):
        self.history = []
        self.max_tokens = max_tokens

    def add_message(self, role, content):
        self.history.append({"role": role, "content": content})
        self.trim_history()

    def get_context(self):
        return self.history

    def trim_history(self):
        total_tokens = sum(len(message["content"]) for message in self.history)
        while total_tokens > self.max_tokens:
            removed_message = self.history.pop(0)
            total_tokens -= len(removed_message["content"])

memory = ConversationMemory(max_tokens=6000)

def handle_conversation(user_input):
    memory.add_message("user", user_input)
    context = memory.get_context()

    try:
        completion = client.chat.completions.create(
            model="meta/llama3-70b-instruct",
            messages=context,
            temperature=0.5,
            top_p=1,
            max_tokens=1024,
            stream=True
        )

        ai_response = ""
        for chunk in completion:
            if chunk.choices[0].delta.content:
                ai_response += chunk.choices[0].delta.content

        memory.add_message("assistant", ai_response)
        return ai_response
    except Exception as e:
        print(f"Error al procesar la solicitud: {e}")
        return None

def buscar_en_internet(query, num_results=5, lang="es"):
    try:
        response = requests.get(f"https://www.google.com/search?q={query}&num={num_results}&hl={lang}")
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        links = [a['href'] for a in soup.find_all('a', href=True) if 'url?q=' in a['href']]
        return [link.split('url?q=')[1].split('&sa=U')[0] for link in links]
    except Exception as e:
        print(f"Error al buscar en internet: {e}")
        return []

def analizar_pagina(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        contenido_principal = soup.find('main') or soup.find('article') or soup
        parrafos = contenido_principal.find_all('p')
        texto_largo = " ".join([p.get_text().strip() for p in parrafos if len(p.get_text().strip()) > 50])
        return texto_largo
    except requests.RequestException as e:
        print(f'Error al acceder a {url}: {e}')
        return ""

def descargar_pdf(url, nombre_archivo):
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(nombre_archivo, 'wb') as file:
            file.write(response.content)
        return nombre_archivo
    except requests.RequestException as e:
        print(f"Error al descargar el PDF: {e}")
        return None

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'  # Ajusta esto si es necesario

def is_digitalized(pdf_path):
    pdf_document = fitz.open(pdf_path)
    first_page = pdf_document.load_page(0)
    text = first_page.get_text()
    return bool(text.strip())

def extract_text_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    num_pages = pdf_document.page_count
    text_by_page = [pdf_document.load_page(page_num).get_text() for page_num in range(num_pages)]
    return text_by_page

def extract_text_from_scanned_pdf(pdf_path):
    images = convert_from_path(pdf_path)
    text_by_page = []
    for image in images:
        image_np = np.array(image)
        gray = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)
        text_by_page.append(text)
    return text_by_page

def extract_text_from_pdf_file(pdf_path):
    if is_digitalized(pdf_path):
        return extract_text_from_pdf(pdf_path)
    else:
        return extract_text_from_scanned_pdf(pdf_path)

def process_request(user_input):
    if "buscar" in user_input:
        query = user_input.replace("buscar", "").strip()
        urls = buscar_en_internet(query)
        for url in urls:
            contenido = analizar_pagina(url)
            if contenido:
                response = handle_conversation(contenido)
                print(f"Assistant: {response}")

    elif "descargar pdf" in user_input:
        url = user_input.replace("descargar pdf", "").strip()
        pdf_path = descargar_pdf(url, "descargado.pdf")
        if pdf_path:
            try:
                text_by_page = extract_text_from_pdf_file(pdf_path)
                for page_text in text_by_page:
                    response = handle_conversation(page_text)
                    print(f"Assistant: {response}")
            except FileNotFoundError as e:
                print(f"Error: {e}")

    else:
        response = handle_conversation(user_input)
        print(f"Assistant: {response}")

# Ejemplo de uso
prompts = [
    "buscar cómo armar un backend",
    "descargar pdf https://example.com/documento.pdf",  # Asegúrate de proporcionar un URL válido de un PDF
    "Describe the significance of the Battle of Hastings."
]

for prompt in prompts:
    process_request(prompt)

# Asegúrate de eliminar el archivo descargado después de usarlo
if os.path.exists("descargado.pdf"):
    os.remove("descargado.pdf")
# Out:
# Error al acceder a https://maps.google.com/maps%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26hl%3Des%26um%3D1%26ie%3DUTF-8%26ved%3D1t:200713%26ictx%3D111&opi=89978449: 404 Client Error: Not Found for url: https://maps.google.com/maps%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26hl%3Des%26um%3D1%26ie%3DUTF-8%26ved%3D1t:200713%26ictx%3D111&opi=89978449
# Error al acceder a /search%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26sca_esv%3D458fc5d25ecd7a59%26sca_upv%3D1%26hl%3Des%26ie%3DUTF-8%26tbm%3Dshop%26source%3Dlnms%26ved%3D1t:200713%26ictx%3D111&opi=89978449: No connection adapters were found for '/search%3Fq%3Dc%25C3%25B3mo%2Barmar%2Bun%2Bbackend%26num%3D5%26sca_esv%3D458fc5d25ecd7a59%26sca_upv%3D1%26hl%3Des%26ie%3DUTF-8%26tbm%3Dshop%26source%3Dlnms%26ved%3D1t:200713%26ictx%3D111&opi=89978449'
# Error al acceder a https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk
# Error al acceder a https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3Ds_0ad5JYkMk
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"[{'type': 'too_short', 'loc': ('body', 'messages'), 'msg': 'List should have at least 1 item after validation, not 0', 'input': [], 'ctx': {'field_type': 'List', 'min_length': 1, 'actual_length': 0}}]","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"9bc8d497-014c-42cc-a472-1165a0e69a14"}
# Assistant: None
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"[{'type': 'too_short', 'loc': ('body', 'messages'), 'msg': 'List should have at least 1 item after validation, not 0', 'input': [], 'ctx': {'field_type': 'List', 'min_length': 1, 'actual_length': 0}}]","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"e29f5fce-6e7e-41ed-bace-31d61224c992"}
# Assistant: None
# Error al acceder a https://www.youtube.com/watch%3Fv%3DpDky0NPvzZ8: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3DpDky0NPvzZ8
# Error al acceder a https://www.youtube.com/watch%3Fv%3DpDky0NPvzZ8: 429 Client Error: Too Many Requests for url: https://www.youtube.com/watch%3Fv%3DpDky0NPvzZ8
# Error al procesar la solicitud: data:{"type":"urn:inference-service:problem-details:bad-request","title":"Bad Request","status":400,"detail":"[{'type': 'too_short', 'loc': ('body', 'messages'), 'msg': 'List should have at least 1 item after validation, not 0', 'input': [], 'ctx': {'field_type': 'List', 'min_length': 1, 'actual_length': 0}}]","instance":"/v2/nvcf/pexec/functions/a88f115a-4a47-4381-ad62-ca25dc33dc1b","requestId":"31d5abb2-3dc4-423e-bf8b-782da785d459"}
# Assistant: None
# Error al acceder a https://accounts.google.com/ServiceLogin%3Fcontinue%3Dhttps://www.google.com/search%253Fq%253Dc%2525C3%2525B3mo%252Barmar%252Bun%252Bbackend%2526num%253D5%2526hl%253Des%26hl%3Des&opi=89978449: 404 Client Error: Not Found for url: https://accounts.google.com/ServiceLogin%3Fcontinue%3Dhttps://www.google.com/search%253Fq%253Dc%2525C3%2525B3mo%252Barmar%252Bun%252Bbackend%2526num%253D5%2526hl%253Des%26hl%3Des&opi=89978449
# Error al descargar el PDF: 500 Server Error: Internal Server Error for url: https://example.com/documento.pdf
# Assistant: The Battle of Hastings, fought on October 14, 1066, was a pivotal event in English history that had far-reaching consequences for the development of England, Europe, and the world. Here are some of the significance of the Battle of Hastings:
#
# 1. **Norman Conquest of England**: The Battle of Hastings marked the beginning of the Norman Conquest of England, which led to the replacement of the Anglo-Saxon ruling class with a new French-speaking elite. This conquest introduced feudalism, a new system of government, and a new culture that would shape England's future.
# 2. **End of Anglo-Saxon Rule**: The battle marked the end of Anglo-Saxon rule in England, which had lasted for centuries. The defeat of King Harold II of England at Hastings led to the decline of the Anglo-Saxon monarchy and the rise of a new ruling class.
# 3. **Introduction of French Language and Culture**: The Norman Conquest introduced French language and culture to England, which would eventually merge with the existing Anglo-Saxon culture to form the English language and culture we know today.
# 4. **Impact on English Language**: The Norman Conquest had a significant impact on the English language, with many French words being incorporated into the English language. This has resulted in English having a unique blend of Germanic and Romance language characteristics.
# 5. **Changes in Government and Politics**: The Battle of Hastings led to significant changes in government and politics in England. The Normans introduced a feudal system of government, where power was held by the king and nobles, and the concept of primogeniture (where the eldest son inherits the throne).
# 6. **Architecture and Art**: The Norman Conquest introduced a new style of architecture, art, and literature to England. The Normans built many castles, churches, and monasteries, which would become characteristic of the English landscape.
# 7. **Shift in Power Dynamics**: The Battle of Hastings marked a shift in power dynamics in Europe, with the Normans establishing themselves as a major power. This led to a period of Norman expansion and influence across Europe.
# 8. **Impact on the Church**: The Norman Conquest had a significant impact on the Church in England, with the Normans introducing a new hierarchy and reforming the Church along continental lines.
# 9. **Creation of a Unified England**: The Battle of Hastings ultimately led to the creation of a unified England, with the Normans establishing a strong central government and a unified system of law and administration.
# 10. **Lasting Legacy**: The Battle of Hastings has left a lasting legacy in English history, with its impact still felt today in language, culture, politics, and architecture.
#
# In summary, the Battle of Hastings was a pivotal event that had far-reaching consequences for England, Europe, and the world. It marked the beginning of a new era in English history, introduced a new culture and language, and had a lasting impact on government, politics, architecture, and art.
